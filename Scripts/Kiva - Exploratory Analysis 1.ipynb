# %%
# Import libraries

import pandas as pd 
import numpy as np 
import os

# %%
# Create path

path = r'/Users/admin/Desktop/Kiva Data Analysis'

# %%
path
# Out:
# '/Users/admin/Desktop/Kiva Data Analysis'

# %%
# Import dataframe 

df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'loan_themes_by_region.csv'))

# %%
df.shape
# Out:
# (15736, 21)

# %%
df.head()
# Out:
#    Partner ID               Field Partner Name                       sector  \
# 0           9  KREDIT Microfinance Institution  General Financial Inclusion
# 1           9  KREDIT Microfinance Institution  General Financial Inclusion
# 2           9  KREDIT Microfinance Institution  General Financial Inclusion
# 3           9  KREDIT Microfinance Institution  General Financial Inclusion
# 4           9  KREDIT Microfinance Institution  General Financial Inclusion
#
#      Loan Theme ID         Loan Theme Type   country forkiva  \
# 0  a1050000000slfi        Higher Education  Cambodia      No
# 1  a10500000068jPe  Vulnerable Populations  Cambodia      No
# 2  a1050000000slfi        Higher Education  Cambodia      No
# 3  a10500000068jPe  Vulnerable Populations  Cambodia      No
# 4  a1050000002X1Uu              Sanitation  Cambodia      No
#
#                   region     geocode_old  ISO  ...  amount  \
# 0       Banteay Meanchey  (13.75, 103.0)  KHM  ...     450
# ...

# %%
df.columns
# Out:
# Index(['Partner ID', 'Field Partner Name', 'sector', 'Loan Theme ID',
#        'Loan Theme Type', 'country', 'forkiva', 'region', 'geocode_old', 'ISO',
#        'number', 'amount', 'LocationName', 'geocode', 'names', 'geo', 'lat',
#        'lon', 'mpi_region', 'mpi_geo', 'rural_pct'],
#       dtype='object')

# %%
# Import dataframe 

df_2 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'kiva_loans.csv'))

# %%
df_2.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %%
# Find unique activities logged 

df_2['activity'].unique()
# Out:
# array(['Fruits & Vegetables', 'Rickshaw', 'Transportation', 'Embroidery',
#        'Milk Sales', 'Services', 'Dairy', 'Beauty Salon', 'Manufacturing',
#        'Food Production/Sales', 'Wholesale', 'General Store',
#        'Clothing Sales', 'Poultry', 'Tailoring', 'Sewing', 'Bakery',
#        'Restaurant', 'Food Stall', 'Farming', 'Construction Supplies',
#        'Personal Products Sales', 'Home Products Sales',
#        'Natural Medicines', 'Fish Selling', 'Education provider',
#        'Shoe Sales', 'Machinery Rental', 'Butcher Shop', 'Pigs',
#        'Personal Expenses', 'Food Market', 'Cosmetics Sales',
#        'Personal Housing Expenses', 'Retail', 'Energy', 'Grocery Store',
#        'Construction', 'Agriculture', 'Motorcycle Transport',
#        'Charcoal Sales', 'Food', 'Pharmacy', 'Fishing', 'Timber Sales',
#        'Cattle', 'Electronics Repair', 'Electronics Sales', 'Vehicle',
#        'Cafe', 'Blacksmith', 'Higher education costs', 'Used Clothing',
# ...

# %%
# Create a list of all activities lenders list for the purpose of their loans 

list_activity = df_2['activity']

# %%
list_activity
# Out:
# 0         Fruits & Vegetables
# 1                    Rickshaw
# 2              Transportation
# 3                  Embroidery
# 4                  Milk Sales
#                  ...
# 671200              Livestock
# 671201              Livestock
# 671202                  Games
# 671203              Livestock
# 671204              Livestock
# Name: activity, Length: 671205, dtype: object

# %%
list_activity.shape
# Out:
# (671205,)

# %%
list_activity.value_counts()
# Out:
# Farming                      72955
# General Store                64729
# Personal Housing Expenses    32448
# Food Production/Sales        28106
# Agriculture                  27023
#                              ...
# Film                            13
# Personal Care Products           7
# Celebrations                     5
# Event Planning                   5
# Adult Care                       2
# Name: activity, Length: 163, dtype: int64

# %% [markdown]
# #### There are 163 activities listed. The top 5 most popular activities for loans are as followed: farming, general store, personal housing expenses, food production/sales, and agriculture. The bottom 5 least popular activities for loans are as followed: film, personal care products, event planning, celebrations, and adult care.

# %%
# View the list_activity series as a dataframe  

df_2['activity'].value_counts().to_frame()
# Out:
#                            activity
# Farming                       72955
# General Store                 64729
# Personal Housing Expenses     32448
# Food Production/Sales         28106
# Agriculture                   27023
# ...                             ...
# Film                             13
# Personal Care Products            7
# Celebrations                      5
# Event Planning                    5
# Adult Care                        2
#
# [163 rows x 1 columns]

# %%
# Create a dataframe from the activity column 

l_a = df_2['activity'].value_counts().to_frame()

# %%
l_a.head(10)
# Out:
#                            activity
# Farming                       72955
# General Store                 64729
# Personal Housing Expenses     32448
# Food Production/Sales         28106
# Agriculture                   27023
# Pigs                          26624
# Retail                        24771
# Clothing Sales                22339
# Home Appliances               20267
# Higher education costs        19742

# %% [markdown]
# Notes: I was puzzled to see "Farming" and "Agriculture" listed as separate activities so, I conducted some quick research to see if there's a difference between the two. According to Kiva's official website, farming is a subcategory under Agriculture. I took a look at current loans in Philippines. As of May 2021, there are 1,574 active loans. The majority of those loans are related to pigs/farming/arigiculture.

# %%
# Command: show all rows in the dataframe 

pd.set_option("display.max_rows", 165)

# View the dataframe 
l_a
# Out:
#                                 activity
# Farming                            72955
# General Store                      64729
# Personal Housing Expenses          32448
# Food Production/Sales              28106
# Agriculture                        27023
# Pigs                               26624
# Retail                             24771
# Clothing Sales                     22339
# Home Appliances                    20267
# Higher education costs             19742
# Fruits & Vegetables                16610
# Grocery Store                      15102
# Livestock                          13095
# Fish Selling                       13060
# Food                               10197
# Fishing                            10066
# Services                            9807
# Poultry                             9783
# Tailoring                           9657
# Animal Sales                        9237
# Food Stall                          8905
# Sewing                              8414
# ...

# %%
# Reset index so that "activity" column can be used as a filter

l_a2 = l_a.reset_index()

# %%
l_a2.head(163)
# Out:
#                               index  activity
# 0                           Farming     72955
# 1                     General Store     64729
# 2         Personal Housing Expenses     32448
# 3             Food Production/Sales     28106
# 4                       Agriculture     27023
# 5                              Pigs     26624
# 6                            Retail     24771
# 7                    Clothing Sales     22339
# 8                   Home Appliances     20267
# 9            Higher education costs     19742
# 10              Fruits & Vegetables     16610
# 11                    Grocery Store     15102
# 12                        Livestock     13095
# 13                     Fish Selling     13060
# 14                             Food     10197
# 15                          Fishing     10066
# 16                         Services      9807
# 17                          Poultry      9783
# 18                        Tailoring      9657
# ...

# %%
# Rename columns 

l_a2.rename(columns = {'index' : 'activities', 'activity' : 'count'}, inplace = False)
# Out:
#                          activities  count
# 0                           Farming  72955
# 1                     General Store  64729
# 2         Personal Housing Expenses  32448
# 3             Food Production/Sales  28106
# 4                       Agriculture  27023
# 5                              Pigs  26624
# 6                            Retail  24771
# 7                    Clothing Sales  22339
# 8                   Home Appliances  20267
# 9            Higher education costs  19742
# 10              Fruits & Vegetables  16610
# 11                    Grocery Store  15102
# 12                        Livestock  13095
# 13                     Fish Selling  13060
# 14                             Food  10197
# 15                          Fishing  10066
# 16                         Services   9807
# 17                          Poultry   9783
# 18                        Tailoring   9657
# 19                     Animal Sales   9237
# 20                       Food Stall   8905
# ...

# %% [markdown]
# Brainstorming here. I want to create a "category" column for the following categories: agriculture, commerce, infrastructure, and education. This might be too time consuming since there's 163 unique activities altogether and not all will be assigned.
#
# However, I want to create a flag to assign activities as either most common (5digit), common (4digit), or least common (3digit and less).

# %%
# Changing gears here. View the dataframe to take a look at ISO and amount 

df.head()
# Out:
#    Partner ID               Field Partner Name                       sector  \
# 0           9  KREDIT Microfinance Institution  General Financial Inclusion
# 1           9  KREDIT Microfinance Institution  General Financial Inclusion
# 2           9  KREDIT Microfinance Institution  General Financial Inclusion
# 3           9  KREDIT Microfinance Institution  General Financial Inclusion
# 4           9  KREDIT Microfinance Institution  General Financial Inclusion
#
#      Loan Theme ID         Loan Theme Type   country forkiva  \
# 0  a1050000000slfi        Higher Education  Cambodia      No
# 1  a10500000068jPe  Vulnerable Populations  Cambodia      No
# 2  a1050000000slfi        Higher Education  Cambodia      No
# 3  a10500000068jPe  Vulnerable Populations  Cambodia      No
# 4  a1050000002X1Uu              Sanitation  Cambodia      No
#
#                   region     geocode_old  ISO  ...  amount  \
# 0       Banteay Meanchey  (13.75, 103.0)  KHM  ...     450
# ...

# %%
# Drop columns 

df.drop(columns=['Partner ID', 'Field Partner Name', 'sector', 'Loan Theme ID',
       'Loan Theme Type', 'country', 'forkiva', 'region', 'geocode_old',
       'number','LocationName', 'geocode', 'names', 'geo', 'lat',
       'lon', 'mpi_region', 'mpi_geo', 'rural_pct'], axis =1)
# Out:
#        ISO  amount
# 0      KHM     450
# 1      KHM   20275
# 2      KHM    9150
# 3      KHM  604950
# 4      KHM     275
# ...    ...     ...
# 15731  ZAF   50000
# 15732  KEN   50000
# 15733  UGA   50000
# 15734  CAN   50000
# 15735  MMR   50000
#
# [15736 rows x 2 columns]

# %%
df_3 = df.drop(columns=['Partner ID', 'Field Partner Name', 'sector', 'Loan Theme ID',
       'Loan Theme Type', 'country', 'forkiva', 'region', 'geocode_old',
       'number','LocationName', 'geocode', 'names', 'geo', 'lat',
       'lon', 'mpi_region', 'mpi_geo', 'rural_pct'], axis =1)

# %%
df_3.head()
# Out:
#    ISO  amount
# 0  KHM     450
# 1  KHM   20275
# 2  KHM    9150
# 3  KHM  604950
# 4  KHM     275

# %%
df_3.value_counts()
# Out:
# ISO  amount
# PHL  225       132
#      125       124
#      325        90
#      200        77
#      425        73
#               ...
# KGZ  12100       1
#      12075       1
#      11875       1
#      11850       1
# ZWE  811550      1
# Length: 8206, dtype: int64

# %%
df_3.describe()
# Out:
#              amount
# count  1.573600e+04
# mean   2.003991e+04
# std    9.636941e+04
# min    2.500000e+01
# 25%    9.500000e+02
# 50%    2.600000e+03
# 75%    8.750000e+03
# max    4.929900e+06

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15736 entries, 0 to 15735
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ISO     15722 non-null  object
#  1   amount  15736 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 246.0+ KB

# %%
type(df_3)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create a dataframe from the ISO column 

df_3_iso = df_3['ISO'].value_counts().to_frame()

# %%
df_3_iso.head(10)
# Out:
#       ISO
# PHL  3467
# ARM  1064
# COL   824
# MEX   716
# VNM   687
# PER   609
# KEN   593
# KHM   567
# SLV   496
# TJK   454

# %% [markdown]
# Notes: According to this list, the top 10 countries with the most loans in place are as followed: <br>
# 01. PHL Philippines <br>
# 02. ARM Armenia <br>
# 03. COL Colombia <br>
# 04. MEX Mexico <br>
# 05. VNM Vietnam <br>
# 06. PER Peru <br>
# 07. KEN Kenya <br>
# 08. KHM Cambodia <br>
# 09. SLV El Salvador<br>
# 10. TJK Tajikistan

# %%
# Rename a column 

df_3_iso.rename(columns = {'ISO' : 'loan_count'})
# Out:
#      loan_count
# PHL        3467
# ARM        1064
# COL         824
# MEX         716
# VNM         687
# PER         609
# KEN         593
# KHM         567
# SLV         496
# TJK         454
# LBN         416
# KGZ         412
# WSM         398
# LSO         336
# UGA         304
# IND         296
# GEO         296
# PSE         285
# MLI         235
# PAK         227
# GHA         210
# IDN         196
# GTM         186
# ECU         173
# HND         166
# BOL         164
# CRI         147
# PRY         140
# ZMB         124
# HTI         122
# JOR         120
# CMR         109
# RWA         104
# NIC         101
# MWI          94
# USA          64
# SLE          63
# UKR          63
# ZAF          61
# MOZ          57
# SEN          48
# ISR          47
# TZA          42
# ZWE          42
# COD          35
# TLS          34
# DOM          30
# NPL          29
# MDA          26
# MMR          25
# BFA          24
# TGO          22
# NGA          20
# LBR          19
# ...
