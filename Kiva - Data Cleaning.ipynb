# %%
# Import libraries

import pandas as pd 
import numpy as np 
import os

# %%
# Create path 
path =  r'/Users/julie.spigner/Desktop/Kiva Data Analysis'

# %%
path
# Out:
# '/Users/julie.spigner/Desktop/Kiva Data Analysis'

# %%
# Import dataframes 
df_loans = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'kiva_loans.csv'), index_col = False)

# %%
df_loc = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'kiva_mpi_region_locations.csv'), index_col = False)

# %% [markdown]
# ## df_loans

# %%
# View dataframe  
df_loans.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
# View descriptive stats  
df_loans.describe()
# Out:
#                  id  funded_amount    loan_amount     partner_id  \
# count  6.712050e+05  671205.000000  671205.000000  657698.000000
# mean   9.932486e+05     785.995061     842.397107     178.199616
# std    1.966113e+05    1130.398941    1198.660073      94.247581
# min    6.530470e+05       0.000000      25.000000       9.000000
# 25%    8.230720e+05     250.000000     275.000000     126.000000
# 50%    9.927800e+05     450.000000     500.000000     145.000000
# 75%    1.163653e+06     900.000000    1000.000000     204.000000
# max    1.340339e+06  100000.000000  100000.000000     536.000000
#
#        term_in_months   lender_count
# count   671205.000000  671205.000000
# mean        13.739022      20.590922
# std          8.598919      28.459551
# min          1.000000       0.000000
# 25%          8.000000       7.000000
# 50%         13.000000      13.000000
# 75%         14.000000      24.000000
# max        158.000000    2986.000000

# %%
# Get info 
df_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  object
#  4   sector              671205 non-null  object
#  5   use                 666973 non-null  object
#  6   country_code        671197 non-null  object
#  7   country             671205 non-null  object
#  8   region              614405 non-null  object
#  9   currency            671205 non-null  object
#  10  partner_id          657698 non-null  float64
#  11  posted_time         671205 non-null  object
#  12  disbursed_time      668809 non-null  object
#  13  funded_time         622874 non-null  object
#  14  term_in_months      671205 non-null  float64
# ...

# %%
# Check for missing values 
df_loans.isnull().sum()
# Out:
# id                         0
# funded_amount              0
# loan_amount                0
# activity                   0
# sector                     0
# use                     4232
# country_code               8
# country                    0
# region                 56800
# currency                   0
# partner_id             13507
# posted_time                0
# disbursed_time          2396
# funded_time            48331
# term_in_months             0
# lender_count               0
# tags                  171416
# borrower_genders        4221
# repayment_interval         0
# date                       0
# dtype: int64

# %% [markdown]
# Notes: There are missing values in 7 columns (use, region, partner_id, disbursed_time, funded_time, tags, borrower_genders). All datatypes of missing values are strings.

# %%
# Check size of dataframe to see ratio of missing values compared to all records 
df_loans.shape
# Out:
# (671205, 20)

# %%
# Create a subset of missing values in df 
df_loans_nan = df_loans[df_loans['region'].isnull() == True]

# %%
df_loans_nan.head(50)
# Out:
#           id  funded_amount  loan_amount                   activity  \
# 5    1080148          250.0        250.0                   Services
# 49    653418          450.0        450.0              General Store
# 54    653380          225.0        225.0                Food Market
# 67   1080150          125.0        125.0                     Energy
# 70    653244         2000.0       2000.0                     Retail
# 99   1080153         5000.0       5000.0      Food Production/Sales
# 102   653399         3975.0       3975.0                 Food Stall
# 111   653376          225.0        225.0                     Retail
# 112   653256         1925.0       2400.0         Electronics Repair
# 114  1080151          125.0        125.0                     Energy
# 135   653384          850.0        850.0                 Blacksmith
# 140   653375         2975.0       2975.0      Food Production/Sales
# 145   653427         1200.0       1200.0          Personal Expenses
# ...

# %% [markdown]
# Notes: This tells me that missing values in region column is not country-specific. In other words, missing labels of regions occur across multiple countries.

# %%
# Find duplicates 
df_loans_dups = df_loans[df_loans.duplicated()]

# %%
# Check for duplicates 
df_loans_dups
# Out:
# Empty DataFrame
# Columns: [id, funded_amount, loan_amount, activity, sector, use, country_code, country, region, currency, partner_id, posted_time, disbursed_time, funded_time, term_in_months, lender_count, tags, borrower_genders, repayment_interval, date]
# Index: []

# %% [markdown]
# Notes: There are no duplicates.

# %%
# View dataframe with more rows 
df_loans.head(100)
# Out:
#          id  funded_amount  loan_amount               activity  \
# 0    653051          300.0        300.0    Fruits & Vegetables
# 1    653053          575.0        575.0               Rickshaw
# 2    653068          150.0        150.0         Transportation
# 3    653063          200.0        200.0             Embroidery
# 4    653084          400.0        400.0             Milk Sales
# ..      ...            ...          ...                    ...
# 95   653381          325.0        325.0            Food Market
# 96   653107          325.0        325.0          General Store
# 97   653217         2200.0       2200.0               Pharmacy
# 98   653345          600.0        600.0    Fruits & Vegetables
# 99  1080153         5000.0       5000.0  Food Production/Sales
#
#             sector                                                use  \
# 0             Food            To buy seasonal, fresh fruits to sell.
# ...

# %%
# View names of columns in the dataframe 
df_loans.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %% [markdown]
# Notes: df_loans looks good. All datatypes are clarified. No critical missing values need to be addressed. All columns are labeled correctly. There are no duplicates.

# %% [markdown]
# ## df_loc

# %%
# View dataframe 
df_loc.head(50)
# Out:
#                  LocationName  ISO      country            region  \
# 0     Badakhshan, Afghanistan  AFG  Afghanistan        Badakhshan
# 1        Badghis, Afghanistan  AFG  Afghanistan           Badghis
# 2        Baghlan, Afghanistan  AFG  Afghanistan           Baghlan
# 3          Balkh, Afghanistan  AFG  Afghanistan             Balkh
# 4         Bamyan, Afghanistan  AFG  Afghanistan            Bamyan
# 5       Daykundi, Afghanistan  AFG  Afghanistan          Daykundi
# 6          Farah, Afghanistan  AFG  Afghanistan             Farah
# 7         Faryab, Afghanistan  AFG  Afghanistan            Faryab
# 8         Ghazni, Afghanistan  AFG  Afghanistan            Ghazni
# 9           Ghor, Afghanistan  AFG  Afghanistan              Ghor
# 10       Helmand, Afghanistan  AFG  Afghanistan           Helmand
# 11         Herat, Afghanistan  AFG  Afghanistan             Herat
# 12       Jawzjan, Afghanistan  AFG  Afghanistan           Jawzjan
# ...

# %%
# Check size of the dataframe 
df_loc.shape
# Out:
# (2772, 9)

# %% [markdown]
# Notes: This dataframe--df_loc--is much smaller compared to df_loans.

# %%
# Gather information 
df_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationName  984 non-null    object
#  1   ISO           1008 non-null   object
#  2   country       1008 non-null   object
#  3   region        984 non-null    object
#  4   world_region  1008 non-null   object
#  5   MPI           984 non-null    float64
#  6   geo           2772 non-null   object
#  7   lat           892 non-null    float64
#  8   lon           892 non-null    float64
# dtypes: float64(3), object(6)
# memory usage: 195.0+ KB

# %% [markdown]
# Notes: All datatypes are labeled correctly.

# %%
# Check for missing values 
df_loc.isnull().sum()
# Out:
# LocationName    1788
# ISO             1764
# country         1764
# region          1788
# world_region    1764
# MPI             1788
# geo                0
# lat             1880
# lon             1880
# dtype: int64

# %% [markdown]
# Notes: There are multiple missing values in all columns except for one (geo). There are only 2,772 rows in the entire dataframe. This means more than half of the dataframe is missing. For reference: 1,386 is half of 2,772. However, the geo column is the most important one and can be used to fill in missing values in some columns. I'm going to take a closer look at the geo column based on missing values in region column to see if this is true.

# %%
# Create a subset to find missing values 
df_loc_nan = df_loc[df_loc['region'].isnull() == True]

# %%
df_loc_nan.head(25)
# Out:
#      LocationName  ISO                                     country region  \
# 34            NaN  ALB                                     Albania    NaN
# 35            NaN  ARM                                     Armenia    NaN
# 36            NaN  AZE                                  Azerbaijan    NaN
# 74            NaN  BIH                      Bosnia and Herzegovina    NaN
# 118           NaN  BRB                                    Barbados    NaN
# 234           NaN  DZA                                     Algeria    NaN
# 413           NaN  IND                                       India    NaN
# 449           NaN  KAZ                                  Kazakhstan    NaN
# 458           NaN  KGZ                                  Kyrgyzstan    NaN
# 510           NaN  LCA                                 Saint Lucia    NaN
# 535           NaN  MDA                        Moldova, Republic of    NaN
# 558           NaN  MDV                                    Maldives    NaN
# ...

# %% [markdown]
# Notes: Apparently (1000.0, 1000.0) is considered a missing value in geo column. Check to see how many values in geo column with records of this.

# %%
# Find specific cells in a column 
df_loc.loc[df_loc['geo'] == '(1000.0, 1000.0)']
# Out:
#             LocationName  ISO       country region             world_region  \
# 34                   NaN  ALB       Albania    NaN  Europe and Central Asia
# 35                   NaN  ARM       Armenia    NaN  Europe and Central Asia
# 36                   NaN  AZE    Azerbaijan    NaN  Europe and Central Asia
# 51          Ouðmð, Benin  BEN         Benin  Ouðmð       Sub-Saharan Africa
# 63    Nord, Burkina Faso  BFA  Burkina Faso   Nord       Sub-Saharan Africa
# ...                  ...  ...           ...    ...                      ...
# 2767                 NaN  NaN           NaN    NaN                      NaN
# 2768                 NaN  NaN           NaN    NaN                      NaN
# 2769                 NaN  NaN           NaN    NaN                      NaN
# 2770                 NaN  NaN           NaN    NaN                      NaN
# 2771                 NaN  NaN           NaN    NaN                      NaN
#
#         MPI               geo  lat  lon
# ...

# %%
# Command pandas not to assign any options regarding the max number of rows to display 
pd.options.display.max_rows = None

# %%
# Find specific cells in a column 
df_loc.loc[df_loc['geo'] == '(1000.0, 1000.0)']
# Out:
#                                            LocationName  ISO  \
# 34                                                  NaN  ALB
# 35                                                  NaN  ARM
# 36                                                  NaN  AZE
# 51                                         Ouðmð, Benin  BEN
# 63                                   Nord, Burkina Faso  BFA
# 74                                                  NaN  BIH
# 86              Potosð, Bolivia, Plurinational State of  BOL
# 93                                        Amapð, Brazil  BRA
# 98                               Espðrito Santo, Brazil  BRA
# 99                                        Goiðs, Brazil  BRA
# 104                                      Paranð, Brazil  BRA
# 105                                     Paraðba, Brazil  BRA
# 106                                        Parð, Brazil  BRA
# 108                                       Piauð, Brazil  BRA
# ...

# %% [markdown]
# Notes: So it looks like there are 1,880 missing values in geo column. The missing values vary across regions and are not location specific. Even though missing values are present in the geo column (and also in lat and long columns), there are enough information in other columns to use to provide location based information (ex: ISO, country, and world_region).

# %% [markdown]
# # df_loan_theme

# %%
# Import dataframe 
df_loan_theme = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'loan_theme_ids.csv'), index_col = False)

# %%
# Check size of dataframe 
df_loan_theme.shape
# Out:
# (779092, 4)

# %%
# View dataframe
df_loan_theme.head(30)
# Out:
#         id    Loan Theme ID          Loan Theme Type  Partner ID
# 0   638631  a1050000000skGl                  General       151.0
# 1   640322  a1050000000skGl                  General       151.0
# 2   641006  a1050000002X1ij         Higher Education       160.0
# 3   641019  a1050000002X1ij         Higher Education       160.0
# 4   641594  a1050000002VbsW  Subsistence Agriculture       336.0
# 5   642256  a1050000000T3oX          Extreme Poverty       217.0
# 6   642311  a1050000000snTK                  General        57.0
# 7   642353  a1050000000T3oX          Extreme Poverty       217.0
# 8   642386  a1050000000wf0f                  General       133.0
# 9   642429  a1050000000wezJ                  General        48.0
# 10  642836  a1050000000wf0f                  General       133.0
# 11  643267  a1050000000T3oX          Extreme Poverty       217.0
# 12  643288  a1050000000wezk                  General        77.0
# ...

# %%
# Check descriptive stats 
df_loan_theme.describe()
# Out:
#                  id     Partner ID
# count  7.790920e+05  764279.000000
# mean   1.047475e+06     180.825840
# std    2.282538e+05      97.914029
# min    6.386310e+05       9.000000
# 25%    8.499768e+05     126.000000
# 50%    1.046528e+06     145.000000
# 75%    1.244768e+06     204.000000
# max    1.444243e+06     557.000000

# %%
# Get info 
df_loan_theme.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 779092 entries, 0 to 779091
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               779092 non-null  int64
#  1   Loan Theme ID    764279 non-null  object
#  2   Loan Theme Type  764279 non-null  object
#  3   Partner ID       764279 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.8+ MB

# %%
# Check for missing values 
df_loan_theme.isnull().sum()
# Out:
# id                     0
# Loan Theme ID      14813
# Loan Theme Type    14813
# Partner ID         14813
# dtype: int64

# %% [markdown]
# Notes: There are 14,813 missing values in 3 columns. There's a total of 779,092 records. This is relatively small. All of the missing values should be removed since there's no valuable information to fill in the missing values from one column to another except for id.

# %%
# Check frequency 
df_loan_theme['Loan Theme Type'].value_counts(dropna = False)
# Out:
# General                                                380693
# Underserved                                             62575
# Agriculture                                             40108
# Rural Inclusion                                         21228
# Water                                                   20131
# Higher Education                                        17728
# General (Women)                                         16566
# Vulnerable Populations                                  16354
# NaN                                                     14813
# Green                                                   13913
# Water and Sanitation                                    12032
# Startup                                                  9887
# Subsistence Agriculture and Solar Lanterns               8597
# Youth                                                    8444
# Subsistence Agriculture                                  8247
# ...

# %% [markdown]
# Notes: Seems like some of the loan theme types are women-specific. Create a flag to note loan theme type to idenify women specific groups.

# %%
# Drop rows with missing values 
df_loan_theme.dropna(inplace = True)

# %%
# Check size of dataframe 
df_loan_theme.shape
# Out:
# (764279, 4)

# %% [markdown]
# Notes: Missing values have been successfully dropped from the dataframe. For reference: 779,092 - 14,813 = 764,279.

# %% [markdown]
# ## df_loan_theme_region

# %%
# Import dataframe 
df_loan_theme_region = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'loan_themes_by_region.csv'), index_col = False)

# %%
# View dataframe 
df_loan_theme_region.head(20)
# Out:
#     Partner ID               Field Partner Name                       sector  \
# 0            9  KREDIT Microfinance Institution  General Financial Inclusion
# 1            9  KREDIT Microfinance Institution  General Financial Inclusion
# 2            9  KREDIT Microfinance Institution  General Financial Inclusion
# 3            9  KREDIT Microfinance Institution  General Financial Inclusion
# 4            9  KREDIT Microfinance Institution  General Financial Inclusion
# 5            9  KREDIT Microfinance Institution  General Financial Inclusion
# 6            9  KREDIT Microfinance Institution  General Financial Inclusion
# 7            9  KREDIT Microfinance Institution  General Financial Inclusion
# 8            9  KREDIT Microfinance Institution  General Financial Inclusion
# 9            9  KREDIT Microfinance Institution  General Financial Inclusion
# 10           9  KREDIT Microfinance Institution  General Financial Inclusion
# ...

# %% [markdown]
# Notes: Seems like there are multiple columns.

# %%
# Gather info 
df_loan_theme_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15736 entries, 0 to 15735
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Partner ID          15736 non-null  int64
#  1   Field Partner Name  15736 non-null  object
#  2   sector              15736 non-null  object
#  3   Loan Theme ID       15736 non-null  object
#  4   Loan Theme Type     15736 non-null  object
#  5   country             15736 non-null  object
#  6   forkiva             15736 non-null  object
#  7   region              15736 non-null  object
#  8   geocode_old         1200 non-null   object
#  9   ISO                 15722 non-null  object
#  10  number              15736 non-null  int64
#  11  amount              15736 non-null  int64
#  12  LocationName        15736 non-null  object
#  13  geocode             13662 non-null  object
#  14  names               13661 non-null  object
# ...

# %%
# Check size of the dataframe 
df_loan_theme_region.shape
# Out:
# (15736, 21)

# %%
# Check for missing values 
df_loan_theme_region.isnull().sum()
# Out:
# Partner ID                0
# Field Partner Name        0
# sector                    0
# Loan Theme ID             0
# Loan Theme Type           0
# country                   0
# forkiva                   0
# region                    0
# geocode_old           14536
# ISO                      14
# number                    0
# amount                    0
# LocationName              0
# geocode                2074
# names                  2075
# geo                       0
# lat                    2074
# lon                    2074
# mpi_region               14
# mpi_geo                6065
# rural_pct              1392
# dtype: int64

# %% [markdown]
# Note: There are multiple missing values in geocode_old column. Perhaps this column should be dropped.

# %%
# Check for duplicates 
df_loan_theme_region_dups = df_loan_theme_region[df_loan_theme_region.duplicated()]

# %%
df_loan_theme_region_dups
# Out:
# Empty DataFrame
# Columns: [Partner ID, Field Partner Name, sector, Loan Theme ID, Loan Theme Type, country, forkiva, region, geocode_old, ISO, number, amount, LocationName, geocode, names, geo, lat, lon, mpi_region, mpi_geo, rural_pct]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Notes: There are no duplicates in the dataframe.

# %%
# Export dataframes
df_loans.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_loans_cleaned.pkl'))

# %%
df_loc.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_loc_cleaned.pkl'))

# %%
df_loan_theme.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_loan_theme_cleaned.pkl'))

# %%
df_loan_theme_region.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_loan_theme_region_cleaned.pkl'))
